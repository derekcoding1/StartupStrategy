# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows',1000)

# %%
datadir = '/Users/liwangzhi/Documents/GitHub/StartupStrategy/data'
# datadir = 'data'
data_startup = pd.read_stata(datadir+"/all_deals.dta")
data_public = pd.read_stata(datadir+"/all_public_firms.dta")

# %% [markdown]
# ## EDAV Startup Database

# %%
data_startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72797 entries, 0 to 72796
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   portfoliocompanyid           72797 non-null  int32
#  1   website                      72797 non-null  object
#  2   dealid                       72797 non-null  object
#  3   portfoliocompany             72797 non-null  object
#  4   background                   72797 non-null  object
#  5   investorsbuyersfirms         72797 non-null  object
#  6   portfoliocompanycountry      72797 non-null  object
#  7   dealdescription              72797 non-null  object
#  8   stage                        72797 non-null  object
#  9   dealdate                     72785 non-null  datetime64[ns]
#  10  dealcurrency                 72797 non-null  object
#  11  dealsizecurrmn               59675 non-null  float64
#  12  dealsizeusdmn                59675 non-null  float64
#  13  portfoliocompanystatus       72797 non-null  object
#  14  dealstatus                   72797 non-null  object
#  15  investorcountry              72797 non-null  object
#  16  investorregion               72797 non-null  object
#  17  investorcity                 72797 non-null  object
#  18  investorstatecounty          72797 non-null  object
#  19  portfoliocompanyregion       72797 non-null  object
#  20  portfoliocompanycity         72797 non-null  object
#  21  portfoliocompanystatecounty  72797 non-null  object
#  22  portfoliocompanywebsite      72797 non-null  object
#  23  companyrevenuecurrmn         431 non-null    float64
#  24  entryrevenuemultiple         390 non-null    float64
#  25  ebitdacurrmn                 173 non-null    float64
#  26  entryebitdamultiple          146 non-null    float64
#  27  investorsbuyersfunds         72797 non-null  object
#  28  industryclassification       72797 non-null  object
#  29  primaryindustry              72797 non-null  object
#  30  subindustries                72797 non-null  object
#  31  industryverticals            72797 non-null  object
#  32  boughtfromsellersfirms       72797 non-null  object
#  33  leadpartners                 72797 non-null  object
#  34  boardrepresentatives         72797 non-null  object
#  35  dealsizeeurmn                59675 non-null  float64
#  36  acquiredshare                178 non-null    float64
#  37  financialadvisorsbuyers      72797 non-null  object
#  38  financialadvisorssellers     72797 non-null  object
#  39  legaladvisorsbuyers          72797 non-null  object
#  40  legaladvisorssellers         72797 non-null  object
#  41  has_no_background            72797 non-null  int8
#  42  incyear                      72797 non-null  int16
#  43  _merge                       72797 non-null  category
#  44  has_website                  72797 non-null  int8
# dtypes: category(1), datetime64[ns](1), float64(8), int16(1), int32(1), int8(2), object(31)
# memory usage: 23.4+ MB

# %%
data_startup.head(3)
# Out:
#    portfoliocompanyid            website   dealid  \
# 0               26178  www.barracuda.com  V114584
# 1               26580   www.fleetcor.com   V18681
# 2               26635  www.leafgroup.com    V4520
#
#               portfoliocompany  \
# 0     Barracuda Networks, Inc.
# 1  FleetCor Technologies, Inc.
# 2              Leaf Group Ltd.
#
#                                           background  \
# 0  Founded in 2002 and based in California, Unite...
# 1  Founded in 2000 and based in Georgia, US, Flee...
# 2  Founded in 2006 and based in California, US, L...
#
#                                 investorsbuyersfirms portfoliocompanycountry  \
# 0                                     Focus Ventures                      US
# 1                                       Bain Capital                      US
# 2  Oak Investment Partners, Generation Partners, ...                      US
#
#                                      dealdescription             stage  \
# 0  In September 2006, Barracuda Networks, Inc. ra...  Series D/Round 4
# 1  In June 2005, FleetCor Technologies raised USD...  Series D/Round 4
# 2  In March 2008, returning investors 3i, Generat...  Series D/Round 4
#
#     dealdate dealcurrency  dealsizecurrmn  dealsizeusdmn  \
# 0 2006-09-26                          NaN            NaN
# 1 2005-06-01          USD            75.0           75.0
# 2 2008-03-24          USD            35.0           35.0
#
#   portfoliocompanystatus dealstatus investorcountry         investorregion  \
# 0               Realised  Completed              US          North America
# 1               Realised  Completed              US          North America
# 2                 Active  Completed          US, UK  North America, Europe
#
#                           investorcity investorstatecounty  \
# 0                            Los Altos                  CA
# 1                               Boston                  MA
# 2  Greenwich, Boston, New York, London          CT, MA, NY
#
#   portfoliocompanyregion portfoliocompanycity portfoliocompanystatecounty  \
# 0          North America             Campbell                          CA
# 1          North America              Atlanta                          GA
# 2          North America         Santa Monica                          CA
#
#   portfoliocompanywebsite  companyrevenuecurrmn  entryrevenuemultiple  \
# 0       www.barracuda.com                   NaN                   NaN
# 1        www.fleetcor.com                   NaN                   NaN
# 2       www.leafgroup.com                   NaN                   NaN
#
#    ebitdacurrmn  entryebitdamultiple  \
# 0           NaN                  NaN
# 1           NaN                  NaN
# 2           NaN                  NaN
#
#                                 investorsbuyersfunds  industryclassification  \
# 0                                  Focus Ventures II  Information Technology
# 1                                                     Information Technology
# 2  Spectrum Equity Investors V, Oak Investment Pa...  Information Technology
#
#              primaryindustry  \
# 0  IT Security/Cybersecurity
# 1                   Software
# 2                   Internet
#
#                                        subindustries  \
# 0  Storage, IT Security/Cybersecurity, Monitoring...
# 1           e-Financial, Accounting/Finance Software
# 2  Advertising Agencies & Media Buyers, eMarketin...
#
#                      industryverticals boughtfromsellersfirms   leadpartners  \
# 0                      Cloud Computing
# 1  Processing & Payment Infrastructure                         Andrew Balson
# 2              AdTech, Cloud Computing                          John Hawkins
#
#   boardrepresentatives  dealsizeeurmn  acquiredshare financialadvisorsbuyers  \
# 0                                 NaN            NaN
# 1                               67.33            NaN
# 2                               31.42            NaN
#
#   financialadvisorssellers legaladvisorsbuyers legaladvisorssellers  \
# 0
# 1
# 2
#
#    has_no_background  incyear       _merge  has_website
# 0                  0     2002  matched (3)            1
# 1                  0     2000  matched (3)            1
# 2                  0     2006  matched (3)            1

# %%
data_startup.duplicated().value_counts()
# Out:
# False    42163
# True     30634
# dtype: int64

# %%
data_startup[data_startup.duplicated()==True].head(4)
# Out:
#        portfoliocompanyid            website   dealid  \
# 13704               26178  www.barracuda.com  V114584
# 13707               26178  www.barracuda.com   V32148
# 13708               26178  www.barracuda.com   V32129
# 13710               26178  www.barracuda.com   V15849
#
#                portfoliocompany  \
# 13704  Barracuda Networks, Inc.
# 13707  Barracuda Networks, Inc.
# 13708  Barracuda Networks, Inc.
# 13710  Barracuda Networks, Inc.
#
#                                               background  \
# 13704  Founded in 2002 and based in California, Unite...
# 13707  Founded in 2002 and based in California, Unite...
# 13708  Founded in 2002 and based in California, Unite...
# 13710  Founded in 2002 and based in California, Unite...
#
#                                     investorsbuyersfirms  \
# 13704                                     Focus Ventures
# 13707
# 13708                Sequoia Capital, Francisco Partners
# 13710  Sequoia Capital, Francisco Partners, Focus Ven...
#
#       portfoliocompanycountry  \
# 13704                      US
# 13707                      US
# 13708                      US
# 13710                      US
#
#                                          dealdescription              stage  \
# 13704  In September 2006, Barracuda Networks, Inc. ra...   Series D/Round 4
# 13707  In October 2009, Barracuda Networks, Inc. rais...  Unspecified Round
# 13708  In October 2012, returning investors Francisco...  Unspecified Round
# 13710  In December 2005, Barracuda Networks, Inc. rai...   Series A/Round 1
#
#         dealdate dealcurrency  dealsizecurrmn  dealsizeusdmn  \
# 13704 2006-09-26                          NaN            NaN
# 13707 2009-10-08          USD            5.61           5.61
# 13708 2012-10-03          USD          130.00         130.00
# 13710 2005-12-22          USD           40.00          40.00
#
#       portfoliocompanystatus dealstatus investorcountry investorregion  \
# 13704               Realised  Completed              US  North America
# 13707               Realised  Completed
# 13708               Realised  Completed              US  North America
# 13710               Realised  Completed              US  North America
#
#                                investorcity investorstatecounty  \
# 13704                             Los Altos                  CA
# 13707
# 13708             Menlo Park, San Francisco                  CA
# 13710  Menlo Park, San Francisco, Los Altos                  CA
#
#       portfoliocompanyregion portfoliocompanycity portfoliocompanystatecounty  \
# 13704          North America             Campbell                          CA
# 13707          North America             Campbell                          CA
# 13708          North America             Campbell                          CA
# 13710          North America             Campbell                          CA
#
#       portfoliocompanywebsite  companyrevenuecurrmn  entryrevenuemultiple  \
# 13704       www.barracuda.com                   NaN                   NaN
# 13707       www.barracuda.com                   NaN                   NaN
# 13708       www.barracuda.com                   NaN                   NaN
# 13710       www.barracuda.com                   NaN                   NaN
#
#        ebitdacurrmn  entryebitdamultiple  \
# 13704           NaN                  NaN
# 13707           NaN                  NaN
# 13708           NaN                  NaN
# 13710           NaN                  NaN
#
#                         investorsbuyersfunds  industryclassification  \
# 13704                      Focus Ventures II  Information Technology
# 13707                                         Information Technology
# 13708    Sequoia Capital US Venture Fund XIV  Information Technology
# 13710  Sequoia Capital XI, Focus Ventures II  Information Technology
#
#                  primaryindustry  \
# 13704  IT Security/Cybersecurity
# 13707  IT Security/Cybersecurity
# 13708  IT Security/Cybersecurity
# 13710  IT Security/Cybersecurity
#
#                                            subindustries industryverticals  \
# 13704  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13707  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13708  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13710  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
#
#       boughtfromsellersfirms  \
# 13704
# 13707
# 13708
# 13710
#
#                                             leadpartners boardrepresentatives  \
# 13704
# 13707
# 13708
# 13710  Jim Goetz, Jayson Yuan, Dipanjan Deb, David Golob
#
#        dealsizeeurmn  acquiredshare financialadvisorsbuyers  \
# 13704            NaN            NaN
# 13707           5.04            NaN
# 13708         116.70            NaN
# 13710          35.91            NaN
#
#       financialadvisorssellers legaladvisorsbuyers legaladvisorssellers  \
# 13704
# 13707
# 13708                                                           Goodwin
# 13710
#
#        has_no_background  incyear       _merge  has_website
# 13704                  0     2002  matched (3)            1
# 13707                  0     2002  matched (3)            1
# 13708                  0     2002  matched (3)            1
# 13710                  0     2002  matched (3)            1

# %%
data_startup.duplicated(['portfoliocompanyid']).value_counts()
# Out:
# True     59093
# False    13704
# dtype: int64

# %%
data_startup.drop_duplicates(["portfoliocompanyid"],keep="first").website.isna().value_counts()
# Out:
# False    13704
# Name: website, dtype: int64

# %%
data_startup.duplicated(['portfoliocompanyid', 'dealid']).value_counts()
# Out:
# False    42163
# True     30634
# dtype: int64

# %%
data_startup[data_startup.duplicated(['portfoliocompanyid', 'dealid'])==True].shape
# Out:
# (30634, 45)

# %% [markdown]
# George: For those duplicated 'portfoliocompanyid' and 'dealid' records, we can only keep the first one. But for a certian 'portfoliocompanyid', we should take into account different 'dealid'.

# %%
data_startup[data_startup.duplicated(['portfoliocompanyid'])==True].head(7)
# Out:
#        portfoliocompanyid            website   dealid  \
# 13704               26178  www.barracuda.com  V114584
# 13705               26178  www.barracuda.com   V32129
# 13706               26178  www.barracuda.com   V32148
# 13707               26178  www.barracuda.com   V32148
# 13708               26178  www.barracuda.com   V32129
# 13709               26178  www.barracuda.com   V15849
# 13710               26178  www.barracuda.com   V15849
#
#                portfoliocompany  \
# 13704  Barracuda Networks, Inc.
# 13705  Barracuda Networks, Inc.
# 13706  Barracuda Networks, Inc.
# 13707  Barracuda Networks, Inc.
# 13708  Barracuda Networks, Inc.
# 13709  Barracuda Networks, Inc.
# 13710  Barracuda Networks, Inc.
#
#                                               background  \
# 13704  Founded in 2002 and based in California, Unite...
# 13705  Founded in 2002 and based in California, Unite...
# 13706  Founded in 2002 and based in California, Unite...
# 13707  Founded in 2002 and based in California, Unite...
# 13708  Founded in 2002 and based in California, Unite...
# 13709  Founded in 2002 and based in California, Unite...
# 13710  Founded in 2002 and based in California, Unite...
#
#                                     investorsbuyersfirms  \
# 13704                                     Focus Ventures
# 13705                Sequoia Capital, Francisco Partners
# 13706
# 13707
# 13708                Sequoia Capital, Francisco Partners
# 13709  Sequoia Capital, Francisco Partners, Focus Ven...
# 13710  Sequoia Capital, Francisco Partners, Focus Ven...
#
#       portfoliocompanycountry  \
# 13704                      US
# 13705                      US
# 13706                      US
# 13707                      US
# 13708                      US
# 13709                      US
# 13710                      US
#
#                                          dealdescription              stage  \
# 13704  In September 2006, Barracuda Networks, Inc. ra...   Series D/Round 4
# 13705  In October 2012, returning investors Francisco...  Unspecified Round
# 13706  In October 2009, Barracuda Networks, Inc. rais...  Unspecified Round
# 13707  In October 2009, Barracuda Networks, Inc. rais...  Unspecified Round
# 13708  In October 2012, returning investors Francisco...  Unspecified Round
# 13709  In December 2005, Barracuda Networks, Inc. rai...   Series A/Round 1
# 13710  In December 2005, Barracuda Networks, Inc. rai...   Series A/Round 1
#
#         dealdate dealcurrency  dealsizecurrmn  dealsizeusdmn  \
# 13704 2006-09-26                          NaN            NaN
# 13705 2012-10-03          USD          130.00         130.00
# 13706 2009-10-08          USD            5.61           5.61
# 13707 2009-10-08          USD            5.61           5.61
# 13708 2012-10-03          USD          130.00         130.00
# 13709 2005-12-22          USD           40.00          40.00
# 13710 2005-12-22          USD           40.00          40.00
#
#       portfoliocompanystatus dealstatus investorcountry investorregion  \
# 13704               Realised  Completed              US  North America
# 13705               Realised  Completed              US  North America
# 13706               Realised  Completed
# 13707               Realised  Completed
# 13708               Realised  Completed              US  North America
# 13709               Realised  Completed              US  North America
# 13710               Realised  Completed              US  North America
#
#                                investorcity investorstatecounty  \
# 13704                             Los Altos                  CA
# 13705             Menlo Park, San Francisco                  CA
# 13706
# 13707
# 13708             Menlo Park, San Francisco                  CA
# 13709  Menlo Park, San Francisco, Los Altos                  CA
# 13710  Menlo Park, San Francisco, Los Altos                  CA
#
#       portfoliocompanyregion portfoliocompanycity portfoliocompanystatecounty  \
# 13704          North America             Campbell                          CA
# 13705          North America             Campbell                          CA
# 13706          North America             Campbell                          CA
# 13707          North America             Campbell                          CA
# 13708          North America             Campbell                          CA
# 13709          North America             Campbell                          CA
# 13710          North America             Campbell                          CA
#
#       portfoliocompanywebsite  companyrevenuecurrmn  entryrevenuemultiple  \
# 13704       www.barracuda.com                   NaN                   NaN
# 13705       www.barracuda.com                   NaN                   NaN
# 13706       www.barracuda.com                   NaN                   NaN
# 13707       www.barracuda.com                   NaN                   NaN
# 13708       www.barracuda.com                   NaN                   NaN
# 13709       www.barracuda.com                   NaN                   NaN
# 13710       www.barracuda.com                   NaN                   NaN
#
#        ebitdacurrmn  entryebitdamultiple  \
# 13704           NaN                  NaN
# 13705           NaN                  NaN
# 13706           NaN                  NaN
# 13707           NaN                  NaN
# 13708           NaN                  NaN
# 13709           NaN                  NaN
# 13710           NaN                  NaN
#
#                         investorsbuyersfunds  industryclassification  \
# 13704                      Focus Ventures II  Information Technology
# 13705    Sequoia Capital US Venture Fund XIV  Information Technology
# 13706                                         Information Technology
# 13707                                         Information Technology
# 13708    Sequoia Capital US Venture Fund XIV  Information Technology
# 13709  Sequoia Capital XI, Focus Ventures II  Information Technology
# 13710  Sequoia Capital XI, Focus Ventures II  Information Technology
#
#                  primaryindustry  \
# 13704  IT Security/Cybersecurity
# 13705  IT Security/Cybersecurity
# 13706  IT Security/Cybersecurity
# 13707  IT Security/Cybersecurity
# 13708  IT Security/Cybersecurity
# 13709  IT Security/Cybersecurity
# 13710  IT Security/Cybersecurity
#
#                                            subindustries industryverticals  \
# 13704  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13705  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13706  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13707  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13708  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13709  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
# 13710  Storage, IT Security/Cybersecurity, Monitoring...   Cloud Computing
#
#       boughtfromsellersfirms  \
# 13704
# 13705
# 13706
# 13707
# 13708
# 13709
# 13710
#
#                                             leadpartners boardrepresentatives  \
# 13704
# 13705
# 13706
# 13707
# 13708
# 13709  Jim Goetz, Jayson Yuan, Dipanjan Deb, David Golob
# 13710  Jim Goetz, Jayson Yuan, Dipanjan Deb, David Golob
#
#        dealsizeeurmn  acquiredshare financialadvisorsbuyers  \
# 13704            NaN            NaN
# 13705         116.70            NaN
# 13706           5.04            NaN
# 13707           5.04            NaN
# 13708         116.70            NaN
# 13709          35.91            NaN
# 13710          35.91            NaN
#
#       financialadvisorssellers legaladvisorsbuyers legaladvisorssellers  \
# 13704
# 13705                                                           Goodwin
# 13706
# 13707
# 13708                                                           Goodwin
# 13709
# 13710
#
#        has_no_background  incyear       _merge  has_website
# 13704                  0     2002  matched (3)            1
# 13705                  0     2002  matched (3)            1
# 13706                  0     2002  matched (3)            1
# 13707                  0     2002  matched (3)            1
# 13708                  0     2002  matched (3)            1
# 13709                  0     2002  matched (3)            1
# 13710                  0     2002  matched (3)            1

# %%
table_year = pd.pivot_table(data_startup.drop_duplicates(["portfoliocompanyid"],keep="first"), 
                       values='portfoliocompanyid', index=['incyear'], 
                       aggfunc=np.count_nonzero, fill_value=0)
table_year
# Out:
#          portfoliocompanyid
# incyear
# 2000                    201
# 2001                    204
# 2002                    176
# 2003                    219
# 2004                    266
# 2005                    287
# 2006                    389
# 2007                    411
# 2008                    406
# 2009                    562
# 2010                    695
# 2011                    875
# 2012                   1126
# 2013                   1267
# 2014                   1497
# 2015                   1585
# 2016                   1398
# 2017                   1139
# 2018                    702
# 2019                    272
# 2020                     27

# %%
f, ax = plt.subplots(figsize=(12, 4))

#sns.set_theme(style="whitegrid")
sns.barplot(x=table_year.index, y=table_year.portfoliocompanyid, color="b")
ax.set_ylabel('# Startups', fontsize = 14)
ax.set_xlabel('Founding Year', fontsize = 14)
ax.set_title('Startup distribution per initial year', fontsize = 18)

sns.despine(left=True, bottom=True)

# %%
table_geo = pd.pivot_table(data_startup.drop_duplicates(["portfoliocompanyid"],keep="first"), 
                       values='portfoliocompanyid', index=['portfoliocompanystatecounty'], 
                       aggfunc=np.count_nonzero, fill_value=0)

new = pd.Series(['', 'AI', 'AK', 'AL', 'AR', 'AZ', 'AK', 'CA', 'CO', 'CT',
                    'CA', 'CO', 'DC', 'DE', 'FL', 'FL', 'FL', 'GA', 'HI',
                     'IA', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
                    'MI', 'MN', 'MO', 'MS', 'MT', 'MD', 'NC', 'ND', 'NE', 'NH', 'NJ',
                    'NM', 'NV', 'NY', 'NJ', 'OH', 'OK', 'OR', 'Oh', 'PA', 'RI',
                    'SC', 'SD', 'TN', 'TX', 'TX', 'UT', 'Ut', 'VA', 'VT', 'WA', 'WI',
                    'WV', 'WY', 'WA'])

table_geo = table_geo.set_index(new)
table_geo = table_geo.groupby(table_geo.index).agg({np.sum})

# %%
df_deals = data_startup.drop_duplicates(["portfoliocompanyid", "dealid"],keep="first")

df_deals.shape
# Out:
# (42163, 45)

# %%
# george: want to see how the rounds distribution acorss companies
deal_cnt = df_deals.portfoliocompanyid.groupby(df_deals.portfoliocompanyid).count()
f, ax = plt.subplots(1,2,figsize=(12,5))
plt.yticks(range(27))
ax[0].hist(deal_cnt,27)
ax[0].set_xlabel('# of Rounds')
ax[0].set_ylabel('# of companies')
ax[1].boxplot(deal_cnt);
ax[1].set_ylabel('# of Rounds');

# %%
# george: to find the interval distribution between rounds of fundings
# gather data by companyid, compute time interval between each funding, store in a new column named 'diff'
# 
#df_deals.groupby(df_deals.portfoliocompanyid).sort_values(by=['dealdate']).head()
df_deals['diff'] = df_deals.sort_values(['portfoliocompanyid','dealdate']).groupby('portfoliocompanyid')['dealdate'].diff()
df_interval = df_deals[['portfoliocompanyid','stage','dealdate','diff']]
# Out:
# /Users/liwangzhi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_interval.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28453 entries, 0 to 72795
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   portfoliocompanyid  28453 non-null  int32
#  1   stage               28453 non-null  object
#  2   dealdate            28453 non-null  datetime64[ns]
#  3   diff                28453 non-null  timedelta64[ns]
# dtypes: datetime64[ns](1), int32(1), object(1), timedelta64[ns](1)
# memory usage: 1000.3+ KB

# %%
df_interval = df_interval.dropna(subset = ['diff'])
df_interval['month'] = round(df_interval['diff']/np.timedelta64(1, 'M'),1)
df_interval.head()
# Out:
#    portfoliocompanyid             stage   dealdate      diff  month
# 0               26178  Series D/Round 4 2006-09-26  278 days    9.1
# 1               26580  Series D/Round 4 2005-06-01  365 days   12.0
# 2               26635  Series D/Round 4 2008-03-24  181 days    5.9
# 5               30010  Series D/Round 4 2010-04-08 1947 days   64.0
# 6               30078  Series C/Round 3 2005-03-04  900 days   29.6

# %%
df_interval.sort_values(by=['portfoliocompanyid','dealdate'])
# Out:
#        portfoliocompanyid              stage   dealdate      diff  month
# 0                   26178   Series D/Round 4 2006-09-26  278 days    9.1
# 13706               26178  Unspecified Round 2009-10-08 1108 days   36.4
# 13705               26178  Unspecified Round 2012-10-03 1091 days   35.8
# 13713               26580   Series B/Round 2 1999-11-01  638 days   21.0
# 13712               26580   Series C/Round 3 2002-05-01  912 days   30.0
# ...                   ...                ...        ...       ...    ...
# 72790              384278   Series A/Round 1 2020-07-21   31 days    1.0
# 72791              384285       Venture Debt 2019-01-28  264 days    8.7
# 72792              384285               Seed 2020-07-23  542 days   17.8
# 13700              384360  Unspecified Round 2020-06-01   77 days    2.5
# 72795              384432  Unspecified Round 2019-11-27   17 days    0.6
#
# [28453 rows x 5 columns]

# %%
#plt.hist(df_interval.iloc[df_interval.where(df_interval.month < 150)]);
round_name = ['Seed','Series A/Round 1','Series B/Round 2','Series C/Round 3','Series D/Round 4']
round_month = {x:[] for x in round_name}
for round_n in round_name:
    round_month[round_n] = df_interval.loc[(df_interval.month < 150) & (df_interval.stage == round_n)].month

# %%
f, ax = plt.subplots(1,5,figsize=(16,8), sharey=True)
i = 0
for round_n in round_name:
    ax[i].hist(round_month[round_n],80);
    ax[i].set_title(round_n)
    ax[i].set_xlabel('time interval(month)')
    i = i +1

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax = sns.boxplot(x="stage", y="month", data=df_interval.loc[(df_interval.month < 150)])
ax.set_yticks(np.arange(0,150,12))
plt.xticks(rotation=45);

# %% [markdown]
# ### George: for the dependent variable, we can only focus on the seed and Series A/ round 1
# Given that we web scraped the page around the time of startup’s seed funding round, things we can take as performance metrics for startups could be:
#
# - value of the seed funding
# - sum of first several rounds of fundings (but it seems there is a long interval)
# - time interval between its seed and its first round of funding

# %%
# george: to see outliers
print('maximum number of rounds of fundings:',deal_cnt.max())
idx = deal_cnt.idxmax()
df_deals.loc[df_deals.portfoliocompanyid == idx].sort_values(by=['dealdate'])
# Out:
# maximum number of rounds of fundings: 27
#        portfoliocompanyid       website   dealid         portfoliocompany  \
# 14402               61715  www.uber.com   V13779  Uber Technologies, Inc.
# 14377               61715  www.uber.com      V77  Uber Technologies, Inc.
# 14361               61715  www.uber.com    V8255  Uber Technologies, Inc.
# 14386               61715  www.uber.com   V13781  Uber Technologies, Inc.
# 14366               61715  www.uber.com   V48330  Uber Technologies, Inc.
# 14390               61715  www.uber.com   V64777  Uber Technologies, Inc.
# 14368               61715  www.uber.com   V77278  Uber Technologies, Inc.
# 14409               61715  www.uber.com   V78128  Uber Technologies, Inc.
# 14370               61715  www.uber.com   V80267  Uber Technologies, Inc.
# 14414               61715  www.uber.com   V82078  Uber Technologies, Inc.
# 14399               61715  www.uber.com   V83922  Uber Technologies, Inc.
# 14375               61715  www.uber.com   V90953  Uber Technologies, Inc.
# 14367               61715  www.uber.com   V91072  Uber Technologies, Inc.
# 14385               61715  www.uber.com   V97416  Uber Technologies, Inc.
# 14369               61715  www.uber.com  V100016  Uber Technologies, Inc.
# 14373               61715  www.uber.com  V104586  Uber Technologies, Inc.
# 14398               61715  www.uber.com  V104949  Uber Technologies, Inc.
# 95                  61715  www.uber.com  V106510  Uber Technologies, Inc.
# 14376               61715  www.uber.com  V107462  Uber Technologies, Inc.
# 14363               61715  www.uber.com  V110116  Uber Technologies, Inc.
# 14371               61715  www.uber.com  V208744  Uber Technologies, Inc.
# 14364               61715  www.uber.com  V208742  Uber Technologies, Inc.
# 14391               61715  www.uber.com  V121407  Uber Technologies, Inc.
# 14395               61715  www.uber.com  V208745  Uber Technologies, Inc.
# 14365               61715  www.uber.com  V133461  Uber Technologies, Inc.
# 14360               61715  www.uber.com  V137240  Uber Technologies, Inc.
# 14380               61715  www.uber.com  V156701  Uber Technologies, Inc.
#
#                                               background  \
# 14402  Founded in 2009 and based in California, US, U...
# 14377  Founded in 2009 and based in California, US, U...
# 14361  Founded in 2009 and based in California, US, U...
# 14386  Founded in 2009 and based in California, US, U...
# 14366  Founded in 2009 and based in California, US, U...
# 14390  Founded in 2009 and based in California, US, U...
# 14368  Founded in 2009 and based in California, US, U...
# 14409  Founded in 2009 and based in California, US, U...
# 14370  Founded in 2009 and based in California, US, U...
# 14414  Founded in 2009 and based in California, US, U...
# 14399  Founded in 2009 and based in California, US, U...
# 14375  Founded in 2009 and based in California, US, U...
# 14367  Founded in 2009 and based in California, US, U...
# 14385  Founded in 2009 and based in California, US, U...
# 14369  Founded in 2009 and based in California, US, U...
# 14373  Founded in 2009 and based in California, US, U...
# 14398  Founded in 2009 and based in California, US, U...
# 95     Founded in 2009 and based in California, US, U...
# 14376  Founded in 2009 and based in California, US, U...
# 14363  Founded in 2009 and based in California, US, U...
# 14371  Founded in 2009 and based in California, US, U...
# 14364  Founded in 2009 and based in California, US, U...
# 14391  Founded in 2009 and based in California, US, U...
# 14395  Founded in 2009 and based in California, US, U...
# 14365  Founded in 2009 and based in California, US, U...
# 14360  Founded in 2009 and based in California, US, U...
# 14380  Founded in 2009 and based in California, US, U...
#
#                                     investorsbuyersfirms  \
# 14402                                 Founder Collective
# 14377  Founder Collective, First Round Capital, Lower...
# 14361  Benchmark Capital, First Round Capital, Lowerc...
# 14386  Menlo Ventures, Lowercase Capital, Benchmark C...
# 14366                         Benchmark Capital, GV, TPG
# 14390  Wellington Management, Menlo Ventures, BlackRo...
# 14368  New Enterprise Associates, Valiant Capital Par...
# 14409                                              Baidu
# 14370                                      Goldman Sachs
# 14414
# 14399                                     Times Internet
# 14375  Times Internet, Microsoft, TEV Team Management...
# 14367                        Tata Capital Private Equity
# 14385                            Caspian Venture Capital
# 14369                                          LetterOne
# 14373                          Toyota Financial Services
# 14398        SBT Venture Capital, Public Investment Fund
# 95     Barclays, Morgan Stanley, Citigroup, Goldman S...
# 14376                                       Didi Chuxing
# 14363                            Kumpulan Wang Persaraan
# 14371                                       FS Investors
# 14364                        Axel Springer SE, G Squared
# 14391                                   Axel Springer SE
# 14395                                      Aster Capital
# 14365  Tencent Investment, Sequoia Capital, Dragoneer...
# 14360  Dragoneer Investment Group, Tencent Investment...
# 14380                           Toyota Motor Corporation
#
#       portfoliocompanycountry  \
# 14402                      US
# 14377                      US
# 14361                      US
# 14386                      US
# 14366                      US
# 14390                      US
# 14368                      US
# 14409                      US
# 14370                      US
# 14414                      US
# 14399                      US
# 14375                      US
# 14367                      US
# 14385                      US
# 14369                      US
# 14373                      US
# 14398                      US
# 95                         US
# 14376                      US
# 14363                      US
# 14371                      US
# 14364                      US
# 14391                      US
# 14395                      US
# 14365                      US
# 14360                      US
# 14380                      US
#
#                                          dealdescription  \
# 14402  In August 2009, Uber Technologies, Inc. raised...
# 14377  In October 2010, UberCab raised USD 1.25 milli...
# 14361  In February 2011, Uber Technologies, Inc. rais...
# 14386  In December 2011, Uber Technologies, Inc. rais...
# 14366  In August 2013, Uber Technologies, Inc. raised...
# 14390  In June 2014, Uber Technologies, Inc. raised U...
# 14368  In December 2014, Uber Technologies, Inc. rais...
# 14409  In December 2014, Uber raised USD 600 million ...
# 14370  In January 2015, Uber Technologies, Inc. recei...
# 14414  In February 2015, Uber expanded its series E f...
# 14399  In March 2015, Uber raised an undisclosed amou...
# 14375  In July 2015, Uber Technologies, Inc. raised U...
# 14367  In August 2015, Tata Opportunites Fund investe...
# 14385  In September 2015, Uber Technologies, Inc rais...
# 14369  In February 2016, Uber Technologies raised USD...
# 14373  In May 2016, Uber raised an undisclosed amount...
# 14398  In June 2016, Uber Technologies raised USD 3.5...
# 95     In July 2016, Uber Technologies raised USD 1.1...
# 14376  In August 2016, Didi Chuxing invested USD 1 bi...
# 14363  In September 2016, Uber Technologies, Inc. rai...
# 14371  In February 2017, Uber Technologies, Inc. rais...
# 14364  In April 2017, Uber Technologies, Inc. raised ...
# 14391  In April 2017, Uber Technologies, Inc. raised ...
# 14395  In October 2017, Uber Technologies, Inc. raise...
# 14365  In December 2017, co-lead new investors Softba...
# 14360  In December 2017, a consortium co-led by new i...
# 14380  In August 2018, Uber Technologies, Inc. raised...
#
#                           stage   dealdate dealcurrency  dealsizecurrmn  \
# 14402                      Seed 2009-08-01          USD            0.20
# 14377                     Angel 2010-10-15          USD            1.25
# 14361          Series A/Round 1 2011-02-14          USD           11.00
# 14386          Series B/Round 2 2011-12-07          USD           37.25
# 14366          Series C/Round 3 2013-08-01          USD          361.20
# 14390          Series D/Round 4 2014-06-06          USD         1200.00
# 14368          Series E/Round 5 2014-12-01          USD         1600.47
# 14409          Series E/Round 5 2014-12-16          USD          600.00
# 14370              Venture Debt 2015-01-21          USD         1600.00
# 14414          Series E/Round 5 2015-02-18          USD         1000.00
# 14399         Unspecified Round 2015-03-23          USD             NaN
# 14375          Series F/Round 6 2015-07-31          USD         1000.00
# 14367         Unspecified Round 2015-08-19          USD          100.00
# 14385         Unspecified Round 2015-09-08          USD             NaN
# 14369         Unspecified Round 2016-02-12          USD          200.00
# 14373         Unspecified Round 2016-05-24          USD             NaN
# 14398          Series G/Round 7 2016-06-01          USD         3500.00
# 95                 Venture Debt 2016-07-07          USD         1150.00
# 14376         Unspecified Round 2016-08-01          USD         1000.00
# 14363          Series G/Round 7 2016-09-23          USD           30.00
# 14371         Unspecified Round 2017-02-21                          NaN
# 14364          Series G/Round 7 2017-04-19          USD             NaN
# 14391         Unspecified Round 2017-04-19          USD             NaN
# 14395         Unspecified Round 2017-10-08          USD             NaN
# 14365         Unspecified Round 2018-01-18          USD         1250.00
# 14360  Secondary Stock Purchase 2018-01-18          USD         7750.00
# 14380         Unspecified Round 2018-08-27          USD          500.00
#
#        dealsizeusdmn portfoliocompanystatus dealstatus  \
# 14402           0.20                 Active  Completed
# 14377           1.25                 Active  Completed
# 14361          11.00                 Active  Completed
# 14386          37.25                 Active  Completed
# 14366         361.20                 Active  Completed
# 14390        1200.00                 Active  Completed
# 14368        1600.47                 Active  Completed
# 14409         600.00                 Active  Completed
# 14370        1600.00                 Active  Completed
# 14414        1000.00                 Active  Completed
# 14399            NaN                 Active  Completed
# 14375        1000.00                 Active  Completed
# 14367         100.00                 Active  Completed
# 14385            NaN                 Active  Completed
# 14369         200.00                 Active  Completed
# 14373            NaN                 Active  Completed
# 14398        3500.00                 Active  Completed
# 95           1150.00                 Active  Completed
# 14376        1000.00                 Active  Completed
# 14363          30.00                 Active  Completed
# 14371            NaN                 Active  Completed
# 14364            NaN                 Active  Completed
# 14391            NaN                 Active  Completed
# 14395            NaN                 Active  Completed
# 14365        1250.00                 Active  Completed
# 14360        7750.00                 Active  Completed
# 14380         500.00                 Active  Completed
#
#                                          investorcountry  \
# 14402                                                 US
# 14377                                                 US
# 14361                                                 US
# 14386                                                 US
# 14366                                                 US
# 14390                                          US, Spain
# 14368    US, Qatar, Switzerland, China, Australia, India
# 14409                                              China
# 14370                                                 US
# 14414
# 14399                                              India
# 14375  India, US, Germany, China, Chile, British Virg...
# 14367                                              India
# 14385                                             Cyprus
# 14369                                         Luxembourg
# 14373                                                 US
# 14398                                   UK, Saudi Arabia
# 95                                                UK, US
# 14376                                              China
# 14363                                           Malaysia
# 14371                                                 US
# 14364                                        Germany, US
# 14391                                            Germany
# 14395                                             France
# 14365                               China, US, UK, Japan
# 14360                               US, China, Japan, UK
# 14380                                              Japan
#
#                                           investorregion  \
# 14402                                      North America
# 14377                                      North America
# 14361                                      North America
# 14386                                      North America
# 14366                                      North America
# 14390                              North America, Europe
# 14368  North America, Middle East, Europe, Asia, Aust...
# 14409                                               Asia
# 14370                                      North America
# 14414
# 14399                                               Asia
# 14375  Asia, North America, Europe, Latin America & C...
# 14367                                               Asia
# 14385                                             Europe
# 14369                                             Europe
# 14373                                      North America
# 14398                                Europe, Middle East
# 95                                 Europe, North America
# 14376                                               Asia
# 14363                                               Asia
# 14371                                      North America
# 14364                              Europe, North America
# 14391                                             Europe
# 14395                                             Europe
# 14365                        Asia, North America, Europe
# 14360                        North America, Asia, Europe
# 14380                                               Asia
#
#                                             investorcity  \
# 14402                                          Cambridge
# 14377             Cambridge, Philadelphia, Hermosa Beach
# 14361  Woodside, Philadelphia, Hermosa Beach, Palo Al...
# 14386  Menlo Park, Hermosa Beach, Woodside, New York,...
# 14366                Woodside, Mountain View, Fort Worth
# 14390  Boston, Menlo Park, New York, Mountain View, M...
# 14368  Menlo Park, San Francisco, Greenwich, Doha, Ge...
# 14409                                            Beijing
# 14370                                           New York
# 14414
# 14399                                          New Delhi
# 14375  New Delhi, Redmond, Essen, Palo Alto, New York...
# 14367                                             Mumbai
# 14385                                           Limassol
# 14369                                         Luxembourg
# 14373
# 14398                                     London, Riyadh
# 95                                      London, New York
# 14376                                            Beijing
# 14363                                       Kuala Lumpur
# 14371                                           La Jolla
# 14364                              Berlin, San Francisco
# 14391                                             Berlin
# 14395                                              Paris
# 14365  Shenzhen, Menlo Park, San Francisco, London, T...
# 14360  San Francisco, Shenzhen, Menlo Park, Tokyo, Lo...
# 14380                                              Aichi
#
#                      investorstatecounty portfoliocompanyregion  \
# 14402                                 MA          North America
# 14377                         MA, PA, CA          North America
# 14361                             CA, PA          North America
# 14386                   CA, NY, PA, Utah          North America
# 14366                             CA, TX          North America
# 14390                         MA, CA, NY          North America
# 14368               CA, CT, NY, Victoria          North America
# 14409                                             North America
# 14370                                 NY          North America
# 14414                                             North America
# 14399                                             North America
# 14375  WA, CA, NY, CT, PA, Guangdong, MA          North America
# 14367                                             North America
# 14385                                             North America
# 14369                                             North America
# 14373                                             North America
# 14398                                             North America
# 95                                    NY          North America
# 14376                                             North America
# 14363                                             North America
# 14371                                 CA          North America
# 14364                                 CA          North America
# 14391                                             North America
# 14395                                             North America
# 14365                  Guangdong, CA, TX          North America
# 14360                  CA, Guangdong, TX          North America
# 14380                                             North America
#
#       portfoliocompanycity portfoliocompanystatecounty  \
# 14402        San Francisco                          CA
# 14377        San Francisco                          CA
# 14361        San Francisco                          CA
# 14386        San Francisco                          CA
# 14366        San Francisco                          CA
# 14390        San Francisco                          CA
# 14368        San Francisco                          CA
# 14409        San Francisco                          CA
# 14370        San Francisco                          CA
# 14414        San Francisco                          CA
# 14399        San Francisco                          CA
# 14375        San Francisco                          CA
# 14367        San Francisco                          CA
# 14385        San Francisco                          CA
# 14369        San Francisco                          CA
# 14373        San Francisco                          CA
# 14398        San Francisco                          CA
# 95           San Francisco                          CA
# 14376        San Francisco                          CA
# 14363        San Francisco                          CA
# 14371        San Francisco                          CA
# 14364        San Francisco                          CA
# 14391        San Francisco                          CA
# 14395        San Francisco                          CA
# 14365        San Francisco                          CA
# 14360        San Francisco                          CA
# 14380        San Francisco                          CA
#
#       portfoliocompanywebsite  companyrevenuecurrmn  entryrevenuemultiple  \
# 14402            www.uber.com                   NaN                   NaN
# 14377            www.uber.com                   NaN                   NaN
# 14361            www.uber.com                   NaN                   NaN
# 14386            www.uber.com                   NaN                   NaN
# 14366            www.uber.com                   NaN                   NaN
# 14390            www.uber.com                   NaN                   NaN
# 14368            www.uber.com                 495.0                  3.23
# 14409            www.uber.com                   NaN                   NaN
# 14370            www.uber.com                 495.0                  3.23
# 14414            www.uber.com                 495.0                  2.02
# 14399            www.uber.com                 495.0                   NaN
# 14375            www.uber.com                 495.0                  2.02
# 14367            www.uber.com                 495.0                  0.20
# 14385            www.uber.com                 495.0                   NaN
# 14369            www.uber.com                1995.0                  0.10
# 14373            www.uber.com                1995.0                   NaN
# 14398            www.uber.com                1995.0                  1.75
# 95               www.uber.com                1995.0                  0.58
# 14376            www.uber.com                1995.0                  0.50
# 14363            www.uber.com                1995.0                  0.02
# 14371            www.uber.com                   NaN                   NaN
# 14364            www.uber.com                3845.0                   NaN
# 14391            www.uber.com                3845.0                   NaN
# 14395            www.uber.com                3845.0                   NaN
# 14365            www.uber.com                7932.0                  0.16
# 14360            www.uber.com                7932.0                  0.98
# 14380            www.uber.com                7932.0                  0.06
#
#        ebitdacurrmn  entryebitdamultiple  \
# 14402           NaN                  NaN
# 14377           NaN                  NaN
# 14361           NaN                  NaN
# 14386           NaN                  NaN
# 14366           NaN                  NaN
# 14390           NaN                  NaN
# 14368           NaN                  NaN
# 14409           NaN                  NaN
# 14370        -633.0                -2.53
# 14414        -633.0                -1.58
# 14399        -633.0                  NaN
# 14375        -633.0                -1.58
# 14367        -633.0                -0.16
# 14385        -633.0                  NaN
# 14369       -1356.0                -0.15
# 14373       -1356.0                  NaN
# 14398       -1356.0                -2.58
# 95          -1356.0                -0.85
# 14376       -1356.0                -0.74
# 14363       -1356.0                -0.02
# 14371           NaN                  NaN
# 14364       -2586.0                  NaN
# 14391       -2586.0                  NaN
# 14395       -2586.0                  NaN
# 14365       -3657.0                -0.34
# 14360       -3657.0                -2.12
# 14380       -3657.0                -0.14
#
#                                     investorsbuyersfunds  \
# 14402                               Founder Collective I
# 14377  Founder Collective I, Lowercase RT, First Roun...
# 14361  Benchmark Capital Partners VII, First Round Ca...
# 14386  Benchmark Capital Partners VII, CrunchFund I, ...
# 14366      Benchmark Capital Partners VII, TPG Growth II
# 14390  KPCB Digital Growth Fund II, Menlo Ventures XI...
# 14368  New Enterprise Associates XIV, GB Private Oppo...
# 14409
# 14370
# 14414
# 14399
# 14375
# 14367                            Tata Opportunities Fund
# 14385
# 14369
# 14373
# 14398
# 95
# 14376
# 14363
# 14371
# 14364                                 G Squared Fund III
# 14391
# 14395                                           Aster VI
# 14365  Dragoneer Opportunities Fund III, Sequoia Capi...
# 14360  Dragoneer Opportunities Fund III, Sequoia Capi...
# 14380
#
#        industryclassification          primaryindustry  \
# 14402  Consumer Discretionary  Transportation Services
# 14377  Consumer Discretionary  Transportation Services
# 14361  Consumer Discretionary  Transportation Services
# 14386  Consumer Discretionary  Transportation Services
# 14366  Consumer Discretionary  Transportation Services
# 14390  Consumer Discretionary  Transportation Services
# 14368  Consumer Discretionary  Transportation Services
# 14409  Consumer Discretionary  Transportation Services
# 14370  Consumer Discretionary  Transportation Services
# 14414  Consumer Discretionary  Transportation Services
# 14399  Consumer Discretionary  Transportation Services
# 14375  Consumer Discretionary  Transportation Services
# 14367  Consumer Discretionary  Transportation Services
# 14385  Consumer Discretionary  Transportation Services
# 14369  Consumer Discretionary  Transportation Services
# 14373  Consumer Discretionary  Transportation Services
# 14398  Consumer Discretionary  Transportation Services
# 95     Consumer Discretionary  Transportation Services
# 14376  Consumer Discretionary  Transportation Services
# 14363  Consumer Discretionary  Transportation Services
# 14371  Consumer Discretionary  Transportation Services
# 14364  Consumer Discretionary  Transportation Services
# 14391  Consumer Discretionary  Transportation Services
# 14395  Consumer Discretionary  Transportation Services
# 14365  Consumer Discretionary  Transportation Services
# 14360  Consumer Discretionary  Transportation Services
# 14380  Consumer Discretionary  Transportation Services
#
#                                            subindustries  \
# 14402  Courier & Delivery Services, Car Hire Services...
# 14377  Courier & Delivery Services, Car Hire Services...
# 14361  Courier & Delivery Services, Car Hire Services...
# 14386  Courier & Delivery Services, Car Hire Services...
# 14366  Courier & Delivery Services, Car Hire Services...
# 14390  Courier & Delivery Services, Car Hire Services...
# 14368  Courier & Delivery Services, Car Hire Services...
# 14409  Courier & Delivery Services, Car Hire Services...
# 14370  Courier & Delivery Services, Car Hire Services...
# 14414  Courier & Delivery Services, Car Hire Services...
# 14399  Courier & Delivery Services, Car Hire Services...
# 14375  Courier & Delivery Services, Car Hire Services...
# 14367  Courier & Delivery Services, Car Hire Services...
# 14385  Courier & Delivery Services, Car Hire Services...
# 14369  Courier & Delivery Services, Car Hire Services...
# 14373  Courier & Delivery Services, Car Hire Services...
# 14398  Courier & Delivery Services, Car Hire Services...
# 95     Courier & Delivery Services, Car Hire Services...
# 14376  Courier & Delivery Services, Car Hire Services...
# 14363  Courier & Delivery Services, Car Hire Services...
# 14371  Courier & Delivery Services, Car Hire Services...
# 14364  Courier & Delivery Services, Car Hire Services...
# 14391  Courier & Delivery Services, Car Hire Services...
# 14395  Courier & Delivery Services, Car Hire Services...
# 14365  Courier & Delivery Services, Car Hire Services...
# 14360  Courier & Delivery Services, Car Hire Services...
# 14380  Courier & Delivery Services, Car Hire Services...
#
#              industryverticals             boughtfromsellersfirms  \
# 14402  E-commerce, Mobile Apps
# 14377  E-commerce, Mobile Apps
# 14361  E-commerce, Mobile Apps
# 14386  E-commerce, Mobile Apps
# 14366  E-commerce, Mobile Apps
# 14390  E-commerce, Mobile Apps
# 14368  E-commerce, Mobile Apps
# 14409  E-commerce, Mobile Apps
# 14370  E-commerce, Mobile Apps
# 14414  E-commerce, Mobile Apps
# 14399  E-commerce, Mobile Apps
# 14375  E-commerce, Mobile Apps
# 14367  E-commerce, Mobile Apps
# 14385  E-commerce, Mobile Apps
# 14369  E-commerce, Mobile Apps
# 14373  E-commerce, Mobile Apps
# 14398  E-commerce, Mobile Apps
# 95     E-commerce, Mobile Apps
# 14376  E-commerce, Mobile Apps
# 14363  E-commerce, Mobile Apps
# 14371  E-commerce, Mobile Apps
# 14364  E-commerce, Mobile Apps
# 14391  E-commerce, Mobile Apps
# 14395  E-commerce, Mobile Apps
# 14365  E-commerce, Mobile Apps
# 14360  E-commerce, Mobile Apps  Menlo Ventures, Benchmark Capital
# 14380  E-commerce, Mobile Apps
#
#                                             leadpartners  \
# 14402
# 14377                                        Chris Sacca
# 14361                 Bill Gurley, Rob Hayes, Alfred Lin
# 14386                         Shawn Carolan, Sunil Raman
# 14366                       David Krane, David Bonderman
# 14390  Andrew Collins, Harrison Miller, Colin Mistele...
# 14368                                        Paul Hudson
# 14409
# 14370
# 14414
# 14399
# 14375
# 14367                                    Padmanabh Sinha
# 14385                  Ziyavudin Magomedov, William Shor
# 14369                Mikhail Fridman, Alexey Reznikovich
# 14373
# 14398
# 95
# 14376
# 14363
# 14371
# 14364
# 14391
# 14395
# 14365
# 14360
# 14380
#
#                     boardrepresentatives  dealsizeeurmn  acquiredshare  \
# 14402                                              0.14            NaN
# 14377                                              0.90            NaN
# 14361                        Bill Gurley           8.03            NaN
# 14386                                             27.84            NaN
# 14366                    David Bonderman         270.83            NaN
# 14390                                            886.56            NaN
# 14368                                           1284.70           3.74
# 14409                                            538.62            NaN
# 14370                                           1358.24            NaN
# 14414                                            878.40            NaN
# 14399                                               NaN            NaN
# 14375                                            913.00            NaN
# 14367                                             89.63            NaN
# 14385  William Shor, Ziyavudin Magomedov            NaN            NaN
# 14369                                            179.88            NaN
# 14373                                               NaN            NaN
# 14398                                           3129.35            NaN
# 95                                              1037.88            NaN
# 14376                                            902.60            NaN
# 14363                                             26.75            NaN
# 14371                                               NaN            NaN
# 14364                                               NaN            NaN
# 14391                                               NaN            NaN
# 14395                                               NaN            NaN
# 14365                                           1017.93            NaN
# 14360                                           6311.16            NaN
# 14380                                            431.04            NaN
#
#       financialadvisorsbuyers financialadvisorssellers  \
# 14402
# 14377
# 14361
# 14386
# 14366
# 14390
# 14368                             RainMaker Securities
# 14409
# 14370
# 14414
# 14399
# 14375         Rainmaker Group          Rainmaker Group
# 14367
# 14385
# 14369
# 14373
# 14398
# 95
# 14376
# 14363
# 14371
# 14364
# 14391
# 14395
# 14365
# 14360
# 14380
#
#           legaladvisorsbuyers legaladvisorssellers  has_no_background  \
# 14402                                                               0
# 14377                                                               0
# 14361                                                               0
# 14386                                                               0
# 14366   Davis Polk & Wardwell                                       0
# 14390  Weil, Gotshal & Manges       Fenwick & West                  0
# 14368     Shearman & Sterling       Fenwick & West                  0
# 14409                                                               0
# 14370                                                               0
# 14414                                                               0
# 14399                                                               0
# 14375   Davis Wright Tremaine                                       0
# 14367     Shearman & Sterling                                       0
# 14385                                                               0
# 14369                                                               0
# 14373                                                               0
# 14398                                                               0
# 95                                                                  0
# 14376                                                               0
# 14363                                                               0
# 14371                                                               0
# 14364                                                               0
# 14391                                                               0
# 14395                                                               0
# 14365                                                               0
# 14360                                                               0
# 14380                                                               0
#
#        incyear       _merge  has_website
# 14402     2009  matched (3)            1
# 14377     2009  matched (3)            1
# 14361     2009  matched (3)            1
# 14386     2009  matched (3)            1
# 14366     2009  matched (3)            1
# 14390     2009  matched (3)            1
# 14368     2009  matched (3)            1
# 14409     2009  matched (3)            1
# 14370     2009  matched (3)            1
# 14414     2009  matched (3)            1
# 14399     2009  matched (3)            1
# 14375     2009  matched (3)            1
# 14367     2009  matched (3)            1
# 14385     2009  matched (3)            1
# 14369     2009  matched (3)            1
# 14373     2009  matched (3)            1
# 14398     2009  matched (3)            1
# 95        2009  matched (3)            1
# 14376     2009  matched (3)            1
# 14363     2009  matched (3)            1
# 14371     2009  matched (3)            1
# 14364     2009  matched (3)            1
# 14391     2009  matched (3)            1
# 14395     2009  matched (3)            1
# 14365     2009  matched (3)            1
# 14360     2009  matched (3)            1
# 14380     2009  matched (3)            1

# %%
table_stage = pd.pivot_table(data_startup.drop_duplicates(["portfoliocompanyid", "dealid"],keep="first"), index = ['stage'],
                       values='dealsizeusdmn', 
                       aggfunc={np.count_nonzero,np.sum, np.mean}, fill_value=0)
table_stage
# Out:
#                           count_nonzero        mean        sum
# stage
# Add-on                             1062  206.398828   26419.05
# Angel                               828    1.061098     705.63
# Grant                               373    2.244762     707.10
# Growth Capital/Expansion            594   35.046645   16506.97
# Merger                               39   82.223333     246.67
# PIPE                                 76   78.016462    5071.07
# Pre-IPO                              12   39.495833     473.95
# Secondary Stock Purchase             92  406.625862   11792.15
# Seed                               9797    2.485661   19077.45
# Series A/Round 1                   7436    9.025216   61308.29
# Series B/Round 2                   4391   19.348119   80139.91
# Series C/Round 3                   2298   33.401460   73216.00
# Series D/Round 4                   1076   52.295521   54178.16
# Series E/Round 5                    452   79.146690   33953.93
# Series F/Round 6                    209  119.258947   22659.20
# Series G/Round 7                     65  252.976349   15937.51
# Series H/Round 8                     18  243.575556    4384.36
# Series I/Round 9                      4  261.045000    1044.18
# Series J/Round 10                     1   50.000000      50.00
# Series K/Round 11                     1  879.830000     879.83
# Unspecified Round                 10390   14.209983  108507.43
# Venture Debt                       2942   20.564644   50876.93

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(16,8), sharey=True)

table_stage = table_stage.sort_values('count_nonzero',ascending=False)
#table_stage2 = table_stage[table_stage.index !='Add-on']


sns.barplot(y=table_stage.index, x=table_stage.iloc[:,0], color="b", ax =ax1)
sns.barplot(y=table_stage.index, x=table_stage.iloc[:,1], color="b", ax =ax2)
sns.barplot(y=table_stage.index, x=table_stage.iloc[:,2], color="b", ax =ax3)


ax1.set_ylabel('Type of Funding', fontsize = 16)
ax1.set_xlabel('# Transactions', fontsize = 16)
ax1.set_title('# Venture Deals', fontsize = 18)
ax1.tick_params(axis='y', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

ax2.set_ylabel('', fontsize = 16)
ax2.set_xlabel('US Millions of Dollar', fontsize = 16)
ax2.set_title('Average size of deal', fontsize = 18)
ax2.tick_params(axis='x', labelsize=14)

ax3.set_ylabel('', fontsize = 16)
ax3.set_xlabel('US Millions of Dollar', fontsize = 16)
ax3.set_title('Total Venture Funding', fontsize = 18)
ax3.tick_params(axis='x', labelsize=14)

plt.tight_layout()

# %%
table_fund_geo_comp = pd.pivot_table(data_startup.drop_duplicates(["portfoliocompanyid", "dealid"],keep="first"), index = ['portfoliocompanystatecounty'],
                       values='dealsizeusdmn', 
                       aggfunc={np.count_nonzero,np.sum}, fill_value=0)

new = pd.Series(['', 'AI', 'AK', 'AL', 'AR', 'AZ', 'AK', 'CA', 'CO', 'CT',
                    'CA', 'CO', 'DC', 'DE', 'FL', 'FL', 'FL', 'GA', 'HI',
                     'IA', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
                    'MI', 'MN', 'MO', 'MS', 'MT', 'MD', 'NC', 'ND', 'NE', 'NH', 'NJ',
                    'NM', 'NV', 'NY', 'NJ', 'OH', 'OK', 'OR', 'Oh', 'PA', 'RI',
                    'SC', 'SD', 'TN', 'TX', 'TX', 'UT', 'Ut', 'VA', 'VT', 'WA', 'WI',
                    'WV', 'WY', 'WA'])

table_fund_geo_comp = table_fund_geo_comp.set_index(new)
table_fund_geo_comp = table_fund_geo_comp.groupby(table_fund_geo_comp.index).agg({np.sum})

# %%
table_geo_tot = table_geo.join(table_fund_geo_comp)
table_geo_tot.columns =['startups', 'deals', 'amt_deals']
table_geo_tot = table_geo_tot.sort_values('startups',ascending=False)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(16,8), sharey=True)

sns.barplot(y=table_geo_tot.index[0:10], x=table_geo_tot.iloc[0:10,0], color="b", ax =ax1)
sns.barplot(y=table_geo_tot.index[0:10], x=table_geo_tot.iloc[0:10,1], color="b", ax =ax2)
sns.barplot(y=table_geo_tot.index[0:10], x=table_geo_tot.iloc[0:10,2], color="b", ax =ax3)


ax1.set_ylabel('Top 10 US States', fontsize = 16)
ax1.set_xlabel('# Startups', fontsize = 16)
ax1.set_title('Startups Distribution', fontsize = 18)
ax1.tick_params(axis='y', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

ax2.set_ylabel('', fontsize = 16)
ax2.set_xlabel('# Deals', fontsize = 16)
ax2.set_title('Deals distribution', fontsize = 18)
ax2.tick_params(axis='x', labelsize=14)

ax3.set_ylabel('', fontsize = 16)
ax3.set_xlabel('US Millions of Dollar', fontsize = 16)
ax3.set_title('Total Venture Funding', fontsize = 18)
ax2.tick_params(axis='x', labelsize=14)

plt.tight_layout()

# %%
table_fund_ind = pd.pivot_table(data_startup.drop_duplicates(["portfoliocompanyid", "dealid"],keep="first"), index = ['industryclassification'],
                       values='dealsizeusdmn', 
                       aggfunc={np.count_nonzero,np.sum}, fill_value=0)

table_fund_ind
# Out:
#                                    count_nonzero        sum
# industryclassification
# Business Services                           1913   21042.44
# Consumer Discretionary                      4437   89479.15
# Energy & Utilities                           845   20760.43
# Financial & Insurance Services              2345   55431.57
# Healthcare                                  2490   38248.01
# Industrials                                  469   14102.79
# Information Technology                     28512  320142.92
# Raw Materials & Natural Resources            194    2311.68
# Real Estate                                   68   15130.91
# Telecoms & Media                             883   11485.87

# %%
table_ind_comp = pd.pivot_table(data_startup.drop_duplicates(["portfoliocompanyid"],keep="first"), index = ['industryclassification'],
                       values='dealsizeusdmn', 
                       aggfunc={np.count_nonzero}, fill_value=0)

table_ind_comp.columns = ['startups']
table_ind_comp
# Out:
#                                    startups
# industryclassification
# Business Services                       600
# Consumer Discretionary                 1610
# Energy & Utilities                      214
# Financial & Insurance Services          741
# Healthcare                              952
# Industrials                             176
# Information Technology                 9038
# Raw Materials & Natural Resources        68
# Real Estate                              25
# Telecoms & Media                        277

# %%
table_ind_tot = table_ind_comp.join(table_fund_ind)
table_ind_tot.columns = ['startups', 'deals', 'amt_deals']
table_ind_tot = table_ind_tot.sort_values('startups',ascending=False)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(16,8), sharey=True)

sns.barplot(y=table_ind_tot.index, x=table_ind_tot.iloc[:,0], color="b", ax =ax1)
sns.barplot(y=table_ind_tot.index, x=table_ind_tot.iloc[:,1], color="b", ax =ax2)
sns.barplot(y=table_ind_tot.index, x=table_ind_tot.iloc[:,2], color="b", ax =ax3)


ax1.set_ylabel('Industry', fontsize = 16)
ax1.set_xlabel('# Startups', fontsize = 16)
ax1.set_title('Startups Distribution', fontsize = 18)
ax1.tick_params(axis='y', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

ax2.set_ylabel('', fontsize = 16)
ax2.set_xlabel('# Deals', fontsize = 16)
ax2.set_title('Deals distribution', fontsize = 18)
ax2.tick_params(axis='x', labelsize=14)

ax3.set_ylabel('', fontsize = 16)
ax3.set_xlabel('US Millions of Dollar', fontsize = 16)
ax3.set_title('Total Venture Funding', fontsize = 18)
ax2.tick_params(axis='x', labelsize=14)

plt.tight_layout()

# %% [markdown]
# ## EDAV Public Companies Database

# %%
data_public.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22333 entries, 0 to 22332
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ÿþmark                            22333 non-null  object
#  1   companyname                       22333 non-null  object
#  2   countryisocode                    22333 non-null  object
#  3   nacerev2corecode4digits           22238 non-null  float64
#  4   conscode                          22333 non-null  object
#  5   lastavailyear                     16320 non-null  float64
#  6   operatingrevenueturnoverthusdlas  22333 non-null  object
#  7   numberofemployeeslastavailyr      22333 non-null  object
#  8   bvdindependenceindicator          22333 non-null  object
#  9   guoname                           22333 non-null  object
#  10  ipodate                           22333 non-null  object
#  11  tickersymbol                      22333 non-null  object
#  12  websiteaddress                    22333 non-null  object
#  13  headquarterswebsiteaddress        22333 non-null  object
#  14  marketcapitalisationmusdlastavai  22333 non-null  object
#  15  marketcapitalisationmusd2020      22333 non-null  object
#  16  marketcapitalisationmusd2019      22333 non-null  object
#  17  marketcapitalisationmusd2018      22333 non-null  object
#  18  marketcapitalisationmusd2017      22333 non-null  object
#  19  marketcapitalisationmusd2016      22333 non-null  object
#  20  marketcapitalisationmusd2015      22333 non-null  object
#  21  marketcapitalisationmusd2014      22333 non-null  object
#  22  marketcapitalisationmusd2013      22333 non-null  object
#  23  marketcapitalisationmusd2012      22333 non-null  object
#  24  marketcapitalisationmusd2011      22333 non-null  object
#  25  marketcapitalisationmusd2010      22333 non-null  object
#  26  marketcapitalisationmusd2009      22333 non-null  object
#  27  marketcapitalisationmusd2008      22333 non-null  object
#  28  marketcapitalisationmusd2007      22333 non-null  object
#  29  marketcapitalisationmusd2006      22333 non-null  object
#  30  marketcapitalisationmusd2005      22333 non-null  object
#  31  netprofitthusdlastavailyr         22333 non-null  object
#  32  netprofitthusd2020                22333 non-null  object
#  33  netprofitthusd2019                22333 non-null  object
#  34  netprofitthusd2018                22333 non-null  object
#  35  netprofitthusd2017                22333 non-null  object
#  36  netprofitthusd2016                22333 non-null  object
#  37  netprofitthusd2015                22333 non-null  object
#  38  netprofitthusd2014                22333 non-null  object
#  39  netprofitthusd2013                22333 non-null  object
#  40  netprofitthusd2012                22333 non-null  object
#  41  netprofitthusd2011                22333 non-null  object
#  42  naics2017corecode4digits          22239 non-null  float64
#  43  ussiccorecode3digits              22240 non-null  float64
#  44  descriptionandhistory             22333 non-null  object
#  45  originallanguageoftradedescripti  22333 non-null  object
#  46  first                             22333 non-null  float32
# dtypes: float32(1), float64(4), object(42)
# memory usage: 8.1+ MB

# %%
data_public.tail(5)
# Out:
#       ÿþmark                        companyname countryisocode  \
# 22328   2546                        ZYNEX, INC.             US
# 22329    625                         ZYNGA INC.             US
# 22330   5144   ZYROX MINING INTERNATIONAL, INC.             US
# 22331   3840                          ZYTO CORP             US
# 22332   5059  ZZLL INFORMATION TECHNOLOGY, INC.             US
#
#        nacerev2corecode4digits conscode  lastavailyear  \
# 22328                   2660.0       C1         2019.0
# 22329                   6311.0       C1         2019.0
# 22330                   2219.0       LF         2019.0
# 22331                   3250.0       LF         2019.0
# 22332                   7911.0       C1         2019.0
#
#       operatingrevenueturnoverthusdlas numberofemployeeslastavailyr  \
# 22328                           45,472                          283
# 22329                        1,321,659                        1,883
# 22330                              220                            3
# 22331                            4,095                           30
# 22332                              277                         n.a.
#
#       bvdindependenceindicator      guoname     ipodate tickersymbol  \
# 22328                       B+  ZYNEX, INC.  29/02/2012         ZYXI
# 22329                       A+   ZYNGA INC.  31/12/2013         ZNGA
# 22330                        U               24/10/2005         ZYRX
# 22331                       B-    ZYTO CORP                     ZYTO
# 22332                       B+               29/12/2003         ZZLL
#
#                   websiteaddress headquarterswebsiteaddress  \
# 22328              www.zynex.com
# 22329              www.zynga.com
# 22330  www.dissolvingplastic.com
# 22331               www.zyto.com
# 22332            www.zzlliti.com
#
#       marketcapitalisationmusdlastavai marketcapitalisationmusd2020  \
# 22328                           257.69                         n.a.
# 22329                         5,789.05                         n.a.
# 22330                             n.a.                         n.a.
# 22331                             n.a.                         n.a.
# 22332                             2.43                         n.a.
#
#       marketcapitalisationmusd2019 marketcapitalisationmusd2018  \
# 22328                       257.69                        97.87
# 22329                     5,789.05                     3,387.20
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         2.43                         4.06
#
#       marketcapitalisationmusd2017 marketcapitalisationmusd2016  \
# 22328                       104.51                         9.38
# 22329                     3,127.15                     1,992.33
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         7.26                         n.a.
#
#       marketcapitalisationmusd2015 marketcapitalisationmusd2014  \
# 22328                        14.17                         5.16
# 22329                     2,140.80                     2,041.40
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         n.a.                         n.a.
#
#       marketcapitalisationmusd2013 marketcapitalisationmusd2012  \
# 22328                        11.52                        21.79
# 22329                     2,506.81                     1,377.91
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         n.a.                         n.a.
#
#       marketcapitalisationmusd2011 marketcapitalisationmusd2010  \
# 22328                        20.96                        18.36
# 22329                         n.a.                         n.a.
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         n.a.                         n.a.
#
#       marketcapitalisationmusd2009 marketcapitalisationmusd2008  \
# 22328                         n.a.                         n.a.
# 22329                         n.a.                         n.a.
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         n.a.                         n.a.
#
#       marketcapitalisationmusd2007 marketcapitalisationmusd2006  \
# 22328                         n.a.                         n.a.
# 22329                         n.a.                         n.a.
# 22330                         n.a.                         n.a.
# 22331                         n.a.                         n.a.
# 22332                         n.a.                         n.a.
#
#       marketcapitalisationmusd2005 netprofitthusdlastavailyr  \
# 22328                         n.a.                     9,492
# 22329                         n.a.                    41,925
# 22330                         n.a.                      n.a.
# 22331                         n.a.                      n.a.
# 22332                         n.a.                       453
#
#       netprofitthusd2020 netprofitthusd2019 netprofitthusd2018  \
# 22328               n.a.              9,492              9,552
# 22329               n.a.             41,925             15,457
# 22330               n.a.               n.a.               n.a.
# 22331               n.a.               n.a.               n.a.
# 22332               n.a.                453               -121
#
#       netprofitthusd2017 netprofitthusd2016 netprofitthusd2015  \
# 22328              7,365                 69             -2,911
# 22329             26,639           -108,173           -121,510
# 22330               n.a.               n.a.               n.a.
# 22331               n.a.               n.a.               n.a.
# 22332               -925               -236               -247
#
#       netprofitthusd2014 netprofitthusd2013 netprofitthusd2012  \
# 22328             -6,199             -7,301              1,553
# 22329           -225,900            -36,982           -209,448
# 22330               n.a.               n.a.               n.a.
# 22331               n.a.               n.a.               n.a.
# 22332               -365               -241               -191
#
#       netprofitthusd2011  naics2017corecode4digits  ussiccorecode3digits  \
# 22328              1,564                    3345.0                 384.0
# 22329           -404,316                    5179.0                 737.0
# 22330               n.a.                    3262.0                 306.0
# 22331               n.a.                    3391.0                 384.0
# 22332                 89                    5615.0                 472.0
#
#                                    descriptionandhistory  \
# 22328  Zynex, Inc., incorporated on December 31, 2001...
# 22329  Zynga Inc., incorporated on October 26, 2007, ...
# 22330
# 22331
# 22332  ZZLL Information Technology, Inc., formerly Gr...
#
#       originallanguageoftradedescripti  first
# 22328                                     1.0
# 22329                                     1.0
# 22330                                     1.0
# 22331                                     1.0
# 22332                                     1.0

# %%
data_public.duplicated().value_counts()
# Out:
# False    22333
# dtype: int64

# %%
d = data_public.ipodate==''
d.value_counts()
# Out:
# False    11502
# True     10831
# Name: ipodate, dtype: int64

# %%
data_public['ipoyear'] = pd.DatetimeIndex(data_public['ipodate']).year

data_public['gp_ipoyear']=['+1999' if x <2000  else  'Mssg' if np.isnan(x) else str(int(x)) for x in data_public.ipoyear ]

# %%
table_year = pd.pivot_table(data_public,
                       values='countryisocode', index=['gp_ipoyear'], 
                       aggfunc=np.count_nonzero, fill_value=0)
table_year
# Out:
#             countryisocode
# gp_ipoyear
# +1999                 4515
# 2000                   495
# 2001                   295
# 2002                   268
# 2003                   255
# 2004                   422
# 2005                   421
# 2006                   442
# 2007                   442
# 2008                   214
# 2009                   196
# 2010                   334
# 2011                   385
# 2012                   412
# 2013                   444
# 2014                   452
# 2015                   336
# 2016                   224
# 2017                   276
# 2018                   339
# 2019                   238
# 2020                    97
# Mssg                 10831

# %%
f, ax = plt.subplots(figsize=(12, 4))

sns.set_theme(style="whitegrid")
sns.barplot(x=table_year.index[1:22], y=table_year.countryisocode[1:22], color="b")
ax.set_ylabel('# Public Companies', fontsize = 14)
ax.set_xlabel('IPO Year', fontsize = 14)
ax.set_title('Startup distribution per IPO year', fontsize = 18)

sns.despine(left=True, bottom=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-4e266dd59f3b> in <module>
#       1 f, ax = plt.subplots(figsize=(12, 4))
#       2
# ----> 3 sns.set_theme(style="whitegrid")
#       4 sns.barplot(x=table_year.index[1:22], y=table_year.countryisocode[1:22], color="b")
#       5 ax.set_ylabel('# Public Companies', fontsize = 14)
#
# AttributeError: module 'seaborn' has no attribute 'set_theme'

# %%
data_public['naic'] = ['-99' if np.isnan(x) else str(int(x))[0:2] for x in data_public.naics2017corecode4digits]

# %%
dict_naic={'11': ['Agriculture, Forestry, Fishing and Hunting'],
'21':['Mining, Quarrying, and Oil and Gas Extraction'],
'22':['Utilities'],
'23':['Construction'],
'31':['Manufacturing'],
'32':['Manufacturing'],
'33':['Manufacturing'],
'42':['Wholesale Trade'],
'44':['Retail Trade'],
'45':['Retail Trade'],
'48':['Transportation and Warehousing'],
'49':['Transportation and Warehousing'],
'51':['Information'],
'52':['Finance and Insurance'],
'53':['Real Estate and Rental and Leasing'],
'54':['Professional, Scientific, and Technical Services'],
'55':['Management of Companies and Enterprises'],
'56':['Administrative and Support and Waste Management and Remediation Services'],
'61':['Educational Services'],
'62':['Health Care and Social Assistance'],
'71':['Arts, Entertainment, and Recreation'],
'72':['Accommodation and Food Services'],
'81':['Other Services (except Public Administration)'],
'92':['Public Administration'],
'-99':['Mssg']}

df_naic = pd.DataFrame.from_dict(dict_naic, orient='index')
df_naic.columns = ['description']
df_naic['naic'] = df_naic.index
df_naic
# Out:
#                                            description naic
# 11          Agriculture, Forestry, Fishing and Hunting   11
# 21       Mining, Quarrying, and Oil and Gas Extraction   21
# 22                                           Utilities   22
# 23                                        Construction   23
# 31                                       Manufacturing   31
# 32                                       Manufacturing   32
# 33                                       Manufacturing   33
# 42                                     Wholesale Trade   42
# 44                                        Retail Trade   44
# 45                                        Retail Trade   45
# 48                      Transportation and Warehousing   48
# 49                      Transportation and Warehousing   49
# 51                                         Information   51
# 52                               Finance and Insurance   52
# 53                  Real Estate and Rental and Leasing   53
# 54    Professional, Scientific, and Technical Services   54
# 55             Management of Companies and Enterprises   55
# 56   Administrative and Support and Waste Managemen...   56
# 61                                Educational Services   61
# 62                   Health Care and Social Assistance   62
# 71                 Arts, Entertainment, and Recreation   71
# 72                     Accommodation and Food Services   72
# 81       Other Services (except Public Administration)   81
# 92                               Public Administration   92
# -99                                               Mssg  -99

# %%
data_complete = pd.merge(data_public, df_naic, on='naic', how='outer')
data_complete.head()
# Out:
#   ÿþmark              companyname countryisocode  nacerev2corecode4digits  \
# 0   5908       1-800 ATTORNEY INC             US                   5819.0
# 1   4264    12 RETECH CORPORATION             US                   5829.0
# 2   5503     2-TRACK GLOBAL, INC.             US                   2651.0
# 3   6533  3D PIONEER SYSTEMS INC.             US                   5829.0
# 4   1851   3D SYSTEMS CORPORATION             US                   5829.0
#
#   conscode  lastavailyear operatingrevenueturnoverthusdlas  \
# 0       C1         2001.0                            6,891
# 1       C1         2019.0                            1,629
# 2       C1         2011.0                               77
# 3       C1         2013.0                                0
# 4       C1         2019.0                          629,094
#
#   numberofemployeeslastavailyr bvdindependenceindicator  \
# 0                           71                        U
# 1                         n.a.                        D
# 2                            1                        U
# 3                         n.a.                       A-
# 4                        2,472                       A+
#
#                   guoname     ipodate tickersymbol         websiteaddress  \
# 0                          17/05/1996         ATTY    www.1800attorney.co
# 1      MR ANGELO PONZETTA  25/09/2015         RETC       www.12retech.com
# 2    2-TRACK GLOBAL, INC.                     TOTG  www.2-trackglobal.com
# 3                          21/09/2012         DPSM     www.3d-pioneer.com
# 4  3D SYSTEMS CORPORATION  26/03/2011          DDD      www.3dsystems.com
#
#   headquarterswebsiteaddress marketcapitalisationmusdlastavai  \
# 0                                                        n.a.
# 1                                                        0.06
# 2                                                        n.a.
# 3                                                        n.a.
# 4                                                    1,036.18
#
#   marketcapitalisationmusd2020 marketcapitalisationmusd2019  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         0.06
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                         n.a.                     1,036.18
#
#   marketcapitalisationmusd2018 marketcapitalisationmusd2017  \
# 0                         n.a.                         n.a.
# 1                         0.69                        14.99
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                     1,161.22                       983.77
#
#   marketcapitalisationmusd2016 marketcapitalisationmusd2015  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         n.a.
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                     1,493.26                       973.96
#
#   marketcapitalisationmusd2014 marketcapitalisationmusd2013  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         n.a.
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                     3,655.71                     9,551.42
#
#   marketcapitalisationmusd2012 marketcapitalisationmusd2011  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         n.a.
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                     3,043.08                       727.76
#
#   marketcapitalisationmusd2010 marketcapitalisationmusd2009  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         n.a.
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                       732.67                         n.a.
#
#   marketcapitalisationmusd2008 marketcapitalisationmusd2007  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         n.a.
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                         n.a.                         n.a.
#
#   marketcapitalisationmusd2006 marketcapitalisationmusd2005  \
# 0                         n.a.                         n.a.
# 1                         n.a.                         n.a.
# 2                         n.a.                         n.a.
# 3                         n.a.                         n.a.
# 4                         n.a.                         n.a.
#
#   netprofitthusdlastavailyr netprofitthusd2020 netprofitthusd2019  \
# 0                    -1,845               n.a.               n.a.
# 1                   -12,147               n.a.            -12,147
# 2                       -31               n.a.               n.a.
# 3                       -45               n.a.               n.a.
# 4                   -69,880               n.a.            -69,880
#
#   netprofitthusd2018 netprofitthusd2017 netprofitthusd2016 netprofitthusd2015  \
# 0               n.a.               n.a.               n.a.               n.a.
# 1             -8,767             -1,419                -46                -42
# 2               n.a.               n.a.               n.a.               n.a.
# 3               n.a.               n.a.               n.a.               n.a.
# 4            -45,505            -66,191            -38,419           -655,492
#
#   netprofitthusd2014 netprofitthusd2013 netprofitthusd2012 netprofitthusd2011  \
# 0               n.a.               n.a.               n.a.               n.a.
# 1                 -5               n.a.               n.a.               n.a.
# 2               n.a.               n.a.               n.a.                -31
# 3               n.a.                -45                 -1                 -1
# 4             11,637             44,107             38,941             35,420
#
#    naics2017corecode4digits  ussiccorecode3digits  \
# 0                    5111.0                 274.0
# 1                    5112.0                 737.0
# 2                    5112.0                 381.0
# 3                    5112.0                 737.0
# 4                    5112.0                 737.0
#
#                                descriptionandhistory  \
# 0  1-800-ATTORNEY, Inc., incorporated on Septembe...
# 1  12 Retech Corporation., incorporated on Septem...
# 2  2-Track Global, Inc. (2-Track), incorporated o...
# 3  3D Pioneer Systems, Inc., formerly Mobile Gami...
# 4  3D Systems Corporation, incorporated on May 14...
#
#   originallanguageoftradedescripti  first  ipoyear gp_ipoyear naic  \
# 0                                     1.0   1996.0      +1999   51
# 1                                     1.0   2015.0       2015   51
# 2                                     1.0      NaN       Mssg   51
# 3                                     1.0   2012.0       2012   51
# 4                                     1.0   2011.0       2011   51
#
#    description
# 0  Information
# 1  Information
# 2  Information
# 3  Information
# 4  Information

# %%
table_ind = pd.pivot_table(data_complete,
                       values='countryisocode', index=['description'], 
                       aggfunc=np.count_nonzero, fill_value=0)
table_ind = table_ind.sort_values('countryisocode',ascending=False)
table_ind
# Out:
#                                                     countryisocode
# description
# Finance and Insurance                                         9035
# Manufacturing                                                 4544
# Information                                                   1785
# Professional, Scientific, and Technical Services              1633
# Mining, Quarrying, and Oil and Gas Extraction                  951
# Management of Companies and Enterprises                        735
# Real Estate and Rental and Leasing                             590
# Wholesale Trade                                                532
# Retail Trade                                                   461
# Administrative and Support and Waste Management...             402
# Transportation and Warehousing                                 285
# Health Care and Social Assistance                              273
# Accommodation and Food Services                                243
# Utilities                                                      235
# Construction                                                   195
# Arts, Entertainment, and Recreation                            139
# Mssg                                                            94
# Educational Services                                            71
# Other Services (except Public Administration)                   68
# Agriculture, Forestry, Fishing and Hunting                      55
# Public Administration                                            6

# %%
f, ax1 = plt.subplots(1,1,figsize=(14,8))

sns.barplot(y=table_ind.index, x=table_ind.iloc[:,0], color="b", ax =ax1)

ax1.set_ylabel('', fontsize = 1)
ax1.set_xlabel('# Companies', fontsize = 16)
ax1.set_title('Public Companies Distribution', fontsize = 18)
ax1.tick_params(axis='y', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

plt.tight_layout()

# %%
data_complete['num_marketcap']=[float('NaN') if x== 'n.a.' else float(x.replace(',', '')) for x in data_complete.marketcapitalisationmusdlastavai]
np.percentile(data_complete.num_marketcap[data_complete.num_marketcap.isna()==False],95)
# Out:
# 14395.9375

# %%
f, ax1 = plt.subplots(1,1,figsize=(14,8))

sns.boxplot(data=data_complete[(data_complete.num_marketcap.isna()==False) & (data_complete.num_marketcap < 14395.9375)], x="num_marketcap", ax=ax1, color='b')

ax1.set_xlabel('US Millions Dollars', fontsize = 16)
ax1.set_title('Distribution last available market capitalization', fontsize = 18)
ax1.tick_params(axis='y', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

plt.tight_layout()
